# %% [markdown]
# # Awesome paper title
#
# Joe Bloggs [![](data:image/png;base64,...)](https://orcid.org/0000-0000-0000-0000) ([Somewhere Univserity](www.duckduckgo.com), [A different somewhere](www.duckduckgo.com))
# Another author ([A different somewhere](www.duckduckgo.com))
# July 22, 2024
#
# My awesome science will cure this unpleasant disease and save the world somehow

# %%
library(dplyr)
# Out:
# Attaching package: 'dplyr'
# The following objects are masked from 'package:stats':
#
#     filter, lag
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # 1. Introduction
#
# Unpleasant disease sucks, see <a href="#fig-awesome-plot" class="quarto-xref">Figure 1</a>.
#
# We can have supplementary figures/tables too, with their own numbering and everything, see <a href="#suppfig-1" class="quarto-xref">Figure S1</a> & <a href="#supptbl-example" class="quarto-xref">Table S1</a>.

# %%
plot(mtcars$mpg, mtcars$hp)

# %% [markdown]
# We can cite other stuff too, [Quarto](www.quarto.org) is pretty neat!([Allaire et al. 2022](#ref-AllaireQuarto2022))
#
# We can even embed stuff plots and tables from other notebooks, <a href="#fig-example" class="quarto-xref">Figure 2</a>! Notice how we get a handy link to the source notebook for the chunk too!
#
# ``` python
# plot(cars$speed, cars$dist)
# ```
#
# <figure id="fig-example">
# <img src="attachment:index_files/figure-ipynb/04_data_analysis-001_first_experiment_analysis-01_first-script-fig-example-output-1.png" />
# <figcaption>Figure 2: Figure example</figcaption>
# </figure>
#
# And here’s a table, <a href="#tbl-example2" class="quarto-xref">Table 1</a>
#
# ``` python
# data.frame(letters = letters[1:3], numbers = 1:3) |>
#   knitr::kable()
# ```
#
# | letters | numbers |
# |:--------|--------:|
# | a       |       1 |
# | b       |       2 |
# | c       |       3 |
#
# Table 1: A table made in another notebook
#
# # 2. Results
#
# I already put them in the introduction, what do you want from me?! I can reference that section though <a href="#sec-intro" class="quarto-xref">Section 1</a>, so that’s neat
#
# ## 2.1 Some particular aspect of the results
#
# We can have subsections too, isn’t this fun
#
# # 3. Discussion
#
# And R is pretty neat too!([2024](#ref-base))
#
# # 4. Supplementary materials
#
# <figure id="suppfig-1">
# <img src="https://placehold.co/600x400.png" />
# <figcaption>Figure S1: A placeholder image</figcaption>
# </figure>
#
# And here a supplementary table
#
# ``` r
# gt::gt(head(mtcars))
# ```
#
# <div id="gmaaxatosw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#gmaaxatosw table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #gmaaxatosw thead, #gmaaxatosw tbody, #gmaaxatosw tfoot, #gmaaxatosw tr, #gmaaxatosw td, #gmaaxatosw th {
#   border-style: none;
# }
#
# #gmaaxatosw p {
#   margin: 0;
#   padding: 0;
# }
#
# #gmaaxatosw .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #gmaaxatosw .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #gmaaxatosw .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #gmaaxatosw .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #gmaaxatosw .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #gmaaxatosw .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #gmaaxatosw .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #gmaaxatosw .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #gmaaxatosw .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #gmaaxatosw .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #gmaaxatosw .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #gmaaxatosw .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #gmaaxatosw .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #gmaaxatosw .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #gmaaxatosw .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #gmaaxatosw .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #gmaaxatosw .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #gmaaxatosw .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #gmaaxatosw .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #gmaaxatosw .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #gmaaxatosw .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #gmaaxatosw .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #gmaaxatosw .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #gmaaxatosw .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #gmaaxatosw .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #gmaaxatosw .gt_left {
#   text-align: left;
# }
#
# #gmaaxatosw .gt_center {
#   text-align: center;
# }
#
# #gmaaxatosw .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #gmaaxatosw .gt_font_normal {
#   font-weight: normal;
# }
#
# #gmaaxatosw .gt_font_bold {
#   font-weight: bold;
# }
#
# #gmaaxatosw .gt_font_italic {
#   font-style: italic;
# }
#
# #gmaaxatosw .gt_super {
#   font-size: 65%;
# }
#
# #gmaaxatosw .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #gmaaxatosw .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #gmaaxatosw .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #gmaaxatosw .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #gmaaxatosw .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #gmaaxatosw .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #gmaaxatosw .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #gmaaxatosw .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #gmaaxatosw div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
#
# | mpg  | cyl | disp | hp  | drat | wt    | qsec  | vs  | am  | gear | carb |
# |------|-----|------|-----|------|-------|-------|-----|-----|------|------|
# | 21.0 | 6   | 160  | 110 | 3.90 | 2.620 | 16.46 | 0   | 1   | 4    | 4    |
# | 21.0 | 6   | 160  | 110 | 3.90 | 2.875 | 17.02 | 0   | 1   | 4    | 4    |
# | 22.8 | 4   | 108  | 93  | 3.85 | 2.320 | 18.61 | 1   | 1   | 4    | 1    |
# | 21.4 | 6   | 258  | 110 | 3.08 | 3.215 | 19.44 | 1   | 0   | 3    | 1    |
# | 18.7 | 8   | 360  | 175 | 3.15 | 3.440 | 17.02 | 0   | 0   | 3    | 2    |
# | 18.1 | 6   | 225  | 105 | 2.76 | 3.460 | 20.22 | 1   | 0   | 3    | 1    |
#
# </div>
#
# Table S1: And here’s a table caption.
#
# ``` r
# # Get session information
# session_info <- sessioninfo::session_info()
#
# # Extract package information
# package_info <- session_info$packages %>%
#   dplyr::select(package, loadedversion, source) %>%
#   dplyr::arrange(package)
#
# # Convert to a data frame
# package_df <- as.data.frame(package_info)
# # Print table
# package_df |>
#   dplyr::group_by(source) |>
#   gt::gt()
# ```
#
# <div id="atvxwqcpnu" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>#atvxwqcpnu table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #atvxwqcpnu thead, #atvxwqcpnu tbody, #atvxwqcpnu tfoot, #atvxwqcpnu tr, #atvxwqcpnu td, #atvxwqcpnu th {
#   border-style: none;
# }
#
# #atvxwqcpnu p {
#   margin: 0;
#   padding: 0;
# }
#
# #atvxwqcpnu .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #atvxwqcpnu .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #atvxwqcpnu .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #atvxwqcpnu .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #atvxwqcpnu .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #atvxwqcpnu .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #atvxwqcpnu .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #atvxwqcpnu .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #atvxwqcpnu .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #atvxwqcpnu .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #atvxwqcpnu .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #atvxwqcpnu .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #atvxwqcpnu .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #atvxwqcpnu .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #atvxwqcpnu .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #atvxwqcpnu .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #atvxwqcpnu .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #atvxwqcpnu .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #atvxwqcpnu .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #atvxwqcpnu .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #atvxwqcpnu .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #atvxwqcpnu .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #atvxwqcpnu .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #atvxwqcpnu .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #atvxwqcpnu .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #atvxwqcpnu .gt_left {
#   text-align: left;
# }
#
# #atvxwqcpnu .gt_center {
#   text-align: center;
# }
#
# #atvxwqcpnu .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #atvxwqcpnu .gt_font_normal {
#   font-weight: normal;
# }
#
# #atvxwqcpnu .gt_font_bold {
#   font-weight: bold;
# }
#
# #atvxwqcpnu .gt_font_italic {
#   font-style: italic;
# }
#
# #atvxwqcpnu .gt_super {
#   font-size: 65%;
# }
#
# #atvxwqcpnu .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #atvxwqcpnu .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #atvxwqcpnu .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #atvxwqcpnu .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #atvxwqcpnu .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #atvxwqcpnu .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #atvxwqcpnu .gt_indent_5 {
#   text-indent: 25px;
# }
#
# #atvxwqcpnu .katex-display {
#   display: inline-flex !important;
#   margin-bottom: 0.75em !important;
# }
#
# #atvxwqcpnu div.Reactable > div.rt-table > div.rt-thead > div.rt-tr.rt-tr-group-header > div.rt-th-group:after {
#   height: 0px !important;
# }
# </style>
#
# | package        | loadedversion |
# |----------------|---------------|
# | CRAN (R 4.4.0) |               |
# | R6             | 2.5.1         |
# | cli            | 3.6.3         |
# | digest         | 0.6.36        |
# | dplyr          | 1.1.4         |
# | evaluate       | 0.24.0        |
# | fansi          | 1.0.6         |
# | fastmap        | 1.2.0         |
# | generics       | 0.1.3         |
# | glue           | 1.7.0         |
# | gt             | 0.11.0        |
# | htmltools      | 0.5.8.1       |
# | htmlwidgets    | 1.6.4         |
# | jsonlite       | 1.8.8         |
# | knitr          | 1.48          |
# | lifecycle      | 1.0.4         |
# | magrittr       | 2.0.3         |
# | pillar         | 1.9.0         |
# | pkgconfig      | 2.0.3         |
# | renv           | 0.16.0        |
# | rlang          | 1.1.4         |
# | rmarkdown      | 2.27          |
# | sass           | 0.4.9         |
# | sessioninfo    | 1.2.2         |
# | tibble         | 3.2.1         |
# | tidyselect     | 1.2.1         |
# | utf8           | 1.2.4         |
# | vctrs          | 0.6.5         |
# | withr          | 3.0.0         |
# | xfun           | 0.46          |
# | xml2           | 1.3.6         |
# | yaml           | 2.3.9         |
#
# </div>
#
# Table S2: A table with the packages used and their versions
#
# Allaire, J. J., Charles Teague, Carlos Scheidegger, Yihui Xie, and Christophe Dervieux. 2022. *Quarto*. <https://doi.org/10.5281/zenodo.5960048>.
#
# R Core Team. 2024. “R: A Language and Environment for Statistical Computing.” <https://www.R-project.org/>.
